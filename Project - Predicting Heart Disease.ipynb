# %%
import pandas as pd 
df = pd.read_csv("dataset.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
import matplotlib.pyplot as plt 

# Assuming 'data' is your DataFrame and 'target' is the column name
# Replace 'data' and 'target' with your actual DataFrame and column name
df['target'].value_counts().plot(kind='bar', color=['green', 'red'])
plt.title('Distribution of Heart Disease')
plt.xlabel('Heart Disease Presence')
plt.ylabel('Count')
plt.xticks([0, 1], ['No Heart Disease', 'Heart Disease'])
plt.show()

# %%
df_no_heart_disease = df[df['target'] == 0]
df_heart_disease = df[df['target'] == 1]

plt.figure(figsize=(10, 6))

# Plotting age distribution for no heart disease
plt.hist(df_no_heart_disease['age'], bins=20, alpha=0.5, label='No Heart Disease')

# Plotting age distribution for heart disease
plt.hist(df_heart_disease['age'], bins=20, alpha=0.5, label='Heart Disease')

plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age by Heart Disease')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
correlation_matrix = df.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8})
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score
import seaborn as sns


X = df.iloc[:, :-1]
y = df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

lr = linear_model.LogisticRegression(max_iter=1000)
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

accuracy_lr = accuracy_score(y_test, y_pred)
print("Logistics Accuracy:", accuracy_lr)

print(f"Confusion matrix for Logistics Regression:")
print(confusion_matrix(y_test, y_pred))

print(f"Classification report:")
print(classification_report(y_test, y_pred))

recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Recall: {recall:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1-score: {f1:.4f}")


cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.title(f'Confusion Matrix for')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
# Out:
# Logistics Accuracy: 0.8131868131868132
# Confusion matrix for Logistics Regression:
# [[32  9]
#  [ 8 42]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        41
#            1       0.82      0.84      0.83        50
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91
#
# Recall: 0.8400
# Precision: 0.8235
# F1-score: 0.8317

# %%
from sklearn.tree import export_graphviz
import graphviz
export_graphviz(lr, out_file='tree.dot', 
                feature_names=x.columns,  # Assuming x contains column names
                class_names=['No Heart Disease', 'Heart Disease'],  # Replace with your class names
                filled=True, rounded=True)

# Render the Graphviz file to visualize the tree
with open('tree.dot') as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)

# %%
from sklearn.tree import DecisionTreeClassifier

x = df.iloc[:, :-1]
Y = df.iloc[:, -1]

x_train, x_test, Y_train, Y_test = train_test_split(x, Y, test_size=0.3, random_state=42)


dt = DecisionTreeClassifier()
dt.fit(x_train,Y_train)

Y_pred_dt = dt.predict(x_test)

accuracy_dt = accuracy_score(Y_test, Y_pred_dt)
print("Decision Tree Classifier:", accuracy_dt)

print(f"Confusion matrix for Logistics Regression:")
print(confusion_matrix(Y_test, Y_pred_dt))

print(f"Classification report:")
print(classification_report(Y_test, Y_pred_dt))

recall = recall_score(Y_test, Y_pred_dt)
precision = precision_score(Y_test, Y_pred_dt)
f1 = f1_score(Y_test, Y_pred_dt)

print(f"Recall: {recall:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1-score: {f1:.4f}")


cm = confusion_matrix(Y_test, Y_pred_dt)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap='Reds', fmt='g')
plt.title(f'Confusion Matrix for')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()
# Out:
# Decision Tree Classifier: 0.7252747252747253
# Confusion matrix for Logistics Regression:
# [[31 10]
#  [15 35]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.76      0.71        41
#            1       0.78      0.70      0.74        50
#
#     accuracy                           0.73        91
#    macro avg       0.73      0.73      0.72        91
# weighted avg       0.73      0.73      0.73        91
#
# Recall: 0.7000
# Precision: 0.7778
# F1-score: 0.7368

# %%
from sklearn.tree import export_graphviz
import graphviz
export_graphviz(dt, out_file='tree.dot', 
                feature_names=x.columns,  # Assuming x contains column names
                class_names=['No Heart Disease', 'Heart Disease'],  # Replace with your class names
                filled=True, rounded=True)

# Render the Graphviz file to visualize the tree
with open('tree.dot') as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier()

x = df.iloc[:,:-1]
y = df.iloc[:, -1]

x_train, x_test, y_train, y_test  = train_test_split(x,y,test_size=0.3, random_state=42)
rf.fit(x_train,y_train)

y_pred_rf = rf.predict(x_test)

accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("Random Forest:", accuracy_rf)

print(f"Confusion matrix for Logistics Regression:")
print(confusion_matrix(y_test, y_pred_rf))

print(f"Classification report:")
print(classification_report(y_test, y_pred_rf))

recall = recall_score(y_test, y_pred_rf)
precision = precision_score(y_test, y_pred_rf)
f1 = f1_score(y_test, y_pred_rf)

print(f"Recall: {recall:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1-score: {f1:.4f}")


cm = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap='Greys', fmt='g')
plt.title(f'Confusion Matrix for')
plt.xlabel('Predicted labels')
plt.ylabel('True')
# Out:
# Random Forest: 0.8021978021978022
# Confusion matrix for Logistics Regression:
# [[33  8]
#  [10 40]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79        41
#            1       0.83      0.80      0.82        50
#
#     accuracy                           0.80        91
#    macro avg       0.80      0.80      0.80        91
# weighted avg       0.80      0.80      0.80        91
#
# Recall: 0.8000
# Precision: 0.8333
# F1-score: 0.8163
# Text(45.722222222222214, 0.5, 'True')

# %%
from sklearn.tree import export_graphviz
import graphviz
export_graphviz(rf, out_file='tree.dot', 
                feature_names=x.columns,  # Assuming x contains column names
                class_names=['No Heart Disease', 'Heart Disease'],  # Replace with your class names
                filled=True, rounded=True)

# Render the Graphviz file to visualize the tree
with open('tree.dot') as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)
